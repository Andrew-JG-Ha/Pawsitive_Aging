# %% [markdown]
# VAE - Pawsitive Aging
# ==============
# The following code was heavily based upon the Keras VAE implmentation code with changes to the architecture and optimizations

# %%
# library includes
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import keras
from keras import layers
from keras.preprocessing.image import img_to_array, load_img
from sklearn.model_selection import train_test_split

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
# data loading from CSV
data_path = "./data_sources/"
processedDogs_path = "./data_sources/images/processed_dogs/"
data_csv_path = "./data_sources/dog_data.csv"

dogCSV = pd.read_csv(data_csv_path)

dogImagesPaths = []
for fileDirectory in dogCSV["fileDirectory"]:
    dogImagesPaths.append(processedDogs_path + fileDirectory)

dogCSV["fullFilePath"] = dogImagesPaths

# removing all the rows that are labeled other than "middle-aged", "old", "young"
properLabels = ["old", "young", "middle-aged"]
dogCSV = dogCSV[dogCSV["label"].isin(properLabels)]
dogCSV
# Out:
#       index  fileDirectory        label  \
# 0         0  dog000000.jpg  middle-aged
# 1         1  dog000001.jpg  middle-aged
# 2         2  dog000002.jpg  middle-aged
# 3         3  dog000003.jpg          old
# 4         4  dog000004.jpg  middle-aged
# ...     ...            ...          ...
# 5570   5570  dog005570.jpg        young
# 5571   5571  dog005571.jpg  middle-aged
# 5572   5572  dog005572.jpg  middle-aged
# 5573   5573  dog005573.jpg        young
# 5574   5574  dog005574.jpg        young
#
#                                            fullFilePath
# 0     ./data_sources/images/processed_dogs/dog000000...
# 1     ./data_sources/images/processed_dogs/dog000001...
# 2     ./data_sources/images/processed_dogs/dog000002...
# 3     ./data_sources/images/processed_dogs/dog000003...
# 4     ./data_sources/images/processed_dogs/dog000004...
# ...                                                 ...
# 5570  ./data_sources/images/processed_dogs/dog005570...
# 5571  ./data_sources/images/processed_dogs/dog005571...
# 5572  ./data_sources/images/processed_dogs/dog005572...
# 5573  ./data_sources/images/processed_dogs/dog005573...
# 5574  ./data_sources/images/processed_dogs/dog005574...
#
# [5453 rows x 4 columns]

# %%
# data preprocessing
loaded_images = []
r_data = []
g_data = []
b_data = []

for imageFilePath in dogCSV["fullFilePath"]:
    img = load_img(imageFilePath, target_size=(150, 150), color_mode='rgb')
    img_array = img_to_array(img) / 255.0
    imageData = np.array(img_array)
    loaded_images.append(imageData)
    r_data.append(np.array(imageData[:, :, 0]).flatten())
    g_data.append(np.array(imageData[:, :, 1]).flatten())
    b_data.append(np.array(imageData[:, :, 2]).flatten())    
    
dogCSV["RGB_data"] = loaded_images
dogCSV["R_data"] = r_data
dogCSV["G_data"] = g_data
dogCSV["B_data"] = b_data

dogCSV
# Out:
#       index  fileDirectory        label  \
# 0         0  dog000000.jpg  middle-aged
# 1         1  dog000001.jpg  middle-aged
# 2         2  dog000002.jpg  middle-aged
# 3         3  dog000003.jpg          old
# 4         4  dog000004.jpg  middle-aged
# ...     ...            ...          ...
# 5570   5570  dog005570.jpg        young
# 5571   5571  dog005571.jpg  middle-aged
# 5572   5572  dog005572.jpg  middle-aged
# 5573   5573  dog005573.jpg        young
# 5574   5574  dog005574.jpg        young
#
#                                            fullFilePath  \
# 0     ./data_sources/images/processed_dogs/dog000000...
# 1     ./data_sources/images/processed_dogs/dog000001...
# 2     ./data_sources/images/processed_dogs/dog000002...
# 3     ./data_sources/images/processed_dogs/dog000003...
# 4     ./data_sources/images/processed_dogs/dog000004...
# ...                                                 ...
# 5570  ./data_sources/images/processed_dogs/dog005570...
# 5571  ./data_sources/images/processed_dogs/dog005571...
# 5572  ./data_sources/images/processed_dogs/dog005572...
# 5573  ./data_sources/images/processed_dogs/dog005573...
# 5574  ./data_sources/images/processed_dogs/dog005574...
#
#                                                RGB_data  \
# 0     [[[0.49411765, 0.43137255, 0.43529412], [0.501...
# 1     [[[0.28235295, 0.39215687, 0.4862745], [0.3098...
# 2     [[[0.32156864, 0.078431375, 0.13725491], [0.32...
# 3     [[[1.0, 0.99607843, 1.0], [0.9529412, 0.933333...
# 4     [[[0.011764706, 0.011764706, 0.011764706], [0....
# ...                                                 ...
# 5570  [[[0.39607844, 0.40392157, 0.4], [0.39607844, ...
# 5571  [[[0.023529412, 0.023529412, 0.023529412], [0....
# 5572  [[[0.6117647, 0.39607844, 0.1764706], [0.63137...
# 5573  [[[0.007843138, 0.007843138, 0.007843138], [0....
# 5574  [[[0.16078432, 0.12156863, 0.08235294], [0.160...
#
#                                                  R_data  \
# 0     [0.49411765, 0.5019608, 0.39607844, 0.43137255...
# 1     [0.28235295, 0.30980393, 0.30980393, 0.2784314...
# 2     [0.32156864, 0.32156864, 0.32156864, 0.3098039...
# 3     [1.0, 0.9529412, 1.0, 0.9490196, 0.9843137, 1....
# 4     [0.011764706, 0.011764706, 0.011764706, 0.0078...
# ...                                                 ...
# 5570  [0.39607844, 0.39607844, 0.4, 0.4, 0.40392157,...
# 5571  [0.023529412, 0.023529412, 0.023529412, 0.0235...
# 5572  [0.6117647, 0.6313726, 0.72156864, 0.43529412,...
# 5573  [0.007843138, 0.003921569, 0.003921569, 0.0039...
# 5574  [0.16078432, 0.16078432, 0.16470589, 0.1725490...
#
#                                                  G_data  \
# 0     [0.43137255, 0.4392157, 0.33333334, 0.36862746...
# 1     [0.39215687, 0.41960785, 0.41960785, 0.3882353...
# 2     [0.078431375, 0.078431375, 0.07058824, 0.05882...
# 3     [0.99607843, 0.93333334, 0.99215686, 0.9137255...
# 4     [0.011764706, 0.011764706, 0.011764706, 0.0078...
# ...                                                 ...
# 5570  [0.40392157, 0.40392157, 0.40784314, 0.4078431...
# 5571  [0.023529412, 0.023529412, 0.023529412, 0.0235...
# 5572  [0.39607844, 0.40392157, 0.50980395, 0.3058823...
# 5573  [0.007843138, 0.003921569, 0.003921569, 0.0039...
# 5574  [0.12156863, 0.12156863, 0.1254902, 0.13333334...
#
#                                                  B_data
# 0     [0.43529412, 0.44313726, 0.3372549, 0.37254903...
# 1     [0.4862745, 0.5137255, 0.5137255, 0.48235294, ...
# 2     [0.13725491, 0.13725491, 0.13333334, 0.1215686...
# 3     [1.0, 0.9490196, 1.0, 0.93333334, 0.95686275, ...
# 4     [0.011764706, 0.011764706, 0.011764706, 0.0078...
# ...                                                 ...
# 5570  [0.4, 0.4, 0.40392157, 0.40392157, 0.40784314,...
# 5571  [0.023529412, 0.023529412, 0.023529412, 0.0235...
# 5572  [0.1764706, 0.21568628, 0.36078432, 0.18431373...
# 5573  [0.007843138, 0.003921569, 0.003921569, 0.0039...
# 5574  [0.08235294, 0.08235294, 0.08627451, 0.0941176...
#
# [5453 rows x 8 columns]

# %%
# splitting the test set and training set (25% test set, 75% training set)
imagesData = dogCSV["RGB_data"]
imageLabels = dogCSV["label"]

imageArr = []
for imageData in imagesData[0:255].to_list():
    imageArr.append(imageData)
X_train_tensor = tf.convert_to_tensor(imageArr)

# %%
X_train_tensor.shape
# Out:
# TensorShape([255, 150, 150, 3])

# %%
# enumerating and mapping the labels to values
labelDictionary = {"middled-aged":0, "old":1, "young":2}

# %%
# defining the encoder
latent_dim = 10
inputShape = (150, 150, 3)

encoder_inputs = keras.Input(shape=inputShape)
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=3, padding="same")(x)
x = layers.Conv2D(128, 5, activation="relu", strides=1, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.Dense(64, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_24 (InputLayer)   │ (None, 150, 150, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_27 (Conv2D)            │ (None, 75, 75, 32)        │             896 │ input_layer_24[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_28 (Conv2D)            │ (None, 25, 25, 64)        │          18,496 │ conv2d_27[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_29 (Conv2D)            │ (None, 25, 25, 128)       │         204,928 │ conv2d_28[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten_9 (Flatten)           │ (None, 80000)             │               0 │ conv2d_29[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_30 (Dense)              │ (None, 128)               │      10,240,128 │ flatten_9[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_31 (Dense)              │ (None, 64)                │           8,256 │ dense_30[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ z_mean (Dense)                │ (None, 10)                │             650 │ dense_31[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ z_log_var (Dense)             │ (None, 10)                │             650 │ dense_31[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ sampling_9 (Sampling)         │ (None, 10)                │               0 │ z_mean[0][0],              │
# │                               │                           │                 │ z_log_var[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 10,474,004 (39.96 MB)
#  Trainable params: 10,474,004 (39.96 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# defining the decoder
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(25 * 25 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((25, 25, 64))(x)
x = layers.Conv2DTranspose(128, 5, activation="relu", strides=1, padding="same")(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=3, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_25 (InputLayer)          │ (None, 10)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_32 (Dense)                     │ (None, 40000)               │         440,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape_15 (Reshape)                 │ (None, 25, 25, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_53                  │ (None, 25, 25, 128)         │         204,928 │
# │ (Conv2DTranspose)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_54                  │ (None, 75, 75, 64)          │          73,792 │
# │ (Conv2DTranspose)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_55                  │ (None, 150, 150, 32)        │          18,464 │
# │ (Conv2DTranspose)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_56                  │ (None, 150, 150, 3)         │             867 │
# │ (Conv2DTranspose)                    │                             │                 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 738,051 (2.82 MB)
#  Trainable params: 738,051 (2.82 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# defining the VAE class
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2),
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }
        
        
    def getPredictions(self, inputs):
        imageSize = 150
        z_mean, z_log_var, z = self.encoder.predict(inputs, verbose = 0)
        decodedImage = self.decoder.predict(z, verbose = 0)
        return decodedImage

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())
vae.fit(X_train_tensor, epochs=30, batch_size=25)
# Out:
# Epoch 1/30
# ERROR! Session/line number was not unique in database. History logging moved to new session 90
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - kl_loss: 0.0082 - loss: 15445.7920 - reconstruction_loss: 15440.6396 - total_loss: 15384.0664
# Epoch 2/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - kl_loss: 0.0013 - loss: 15421.5674 - reconstruction_loss: 15416.7979 - total_loss: 15364.3340
# Epoch 3/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - kl_loss: 2.8057e-04 - loss: 15373.1436 - reconstruction_loss: 15376.4121 - total_loss: 15412.3662
# Epoch 4/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - kl_loss: 3.7474e-04 - loss: 15412.1475 - reconstruction_loss: 15409.2412 - total_loss: 15377.2773
# Epoch 5/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - kl_loss: 8.2003e-04 - loss: 15378.3613 - reconstruction_loss: 15378.7422 - total_loss: 15382.9316
# Epoch 6/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - kl_loss: 0.0106 - loss: 15344.1426 - reconstruction_loss: 15347.2227 - total_loss: 15381.2373
# Epoch 7/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - kl_loss: 0.0482 - loss: 15421.2383 - reconstruction_loss: 15417.8242 - total_loss: 15380.8428
# Epoch 8/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - kl_loss: 0.0056 - loss: 15414.1611 - reconstruction_loss: 15412.0479 - total_loss: 15388.8652
# Epoch 9/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - kl_loss: 0.3169 - loss: 15301.4502 - reconstruction_loss: 15308.3281 - total_loss: 15387.7910
# Epoch 10/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - kl_loss: 4.4089 - loss: 15344.2471 - reconstruction_loss: 15339.3193 - total_loss: 15338.0127
# Epoch 11/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - kl_loss: 16.1395 - loss: 15132.1074 - reconstruction_loss: 15109.4443 - total_loss: 15053.8311
# Epoch 12/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - kl_loss: 17.6893 - loss: 14815.0332 - reconstruction_loss: 14790.8066 - total_loss: 14736.5938
# Epoch 13/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - kl_loss: 24.7453 - loss: 14486.1113 - reconstruction_loss: 14459.0898 - total_loss: 14458.7812
# Epoch 14/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - kl_loss: 33.3579 - loss: 14316.4424 - reconstruction_loss: 14282.9238 - total_loss: 14314.4961
# Epoch 15/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - kl_loss: 33.7954 - loss: 14202.8506 - reconstruction_loss: 14169.6523 - total_loss: 14210.0166
# Epoch 16/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - kl_loss: 34.3124 - loss: 14040.7803 - reconstruction_loss: 14013.0664 - total_loss: 14119.9434
# Epoch 17/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - kl_loss: 32.8426 - loss: 14049.2158 - reconstruction_loss: 14009.5889 - total_loss: 13967.8135
# Epoch 18/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - kl_loss: 29.5564 - loss: 14036.7148 - reconstruction_loss: 14007.1875 - total_loss: 14037.0713
# Epoch 19/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - kl_loss: 29.8193 - loss: 14034.5605 - reconstruction_loss: 14002.0781 - total_loss: 14002.6025
# Epoch 20/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - kl_loss: 31.7066 - loss: 13908.8760 - reconstruction_loss: 13887.2061 - total_loss: 14029.3193
# Epoch 21/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - kl_loss: 30.9766 - loss: 13984.9492 - reconstruction_loss: 13952.4990 - total_loss: 13967.2539
# Epoch 22/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - kl_loss: 32.2565 - loss: 13788.3291 - reconstruction_loss: 13762.6455 - total_loss: 13867.2061
# Epoch 23/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - kl_loss: 30.9716 - loss: 13896.2109 - reconstruction_loss: 13862.1641 - total_loss: 13859.3135
# Epoch 24/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - kl_loss: 31.4794 - loss: 13885.5381 - reconstruction_loss: 13844.0830 - total_loss: 13765.8213
# Epoch 25/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - kl_loss: 31.8141 - loss: 13775.4189 - reconstruction_loss: 13737.2764 - total_loss: 13699.4746
# Epoch 26/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - kl_loss: 32.4975 - loss: 13785.0107 - reconstruction_loss: 13741.3945 - total_loss: 13651.5820
# Epoch 27/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - kl_loss: 30.6961 - loss: 13778.2051 - reconstruction_loss: 13731.4932 - total_loss: 13586.0059
# Epoch 28/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - kl_loss: 32.6524 - loss: 13597.8633 - reconstruction_loss: 13574.1387 - total_loss: 13705.0117
# Epoch 29/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - kl_loss: 34.2706 - loss: 13632.6230 - reconstruction_loss: 13600.4297 - total_loss: 13657.5508
# Epoch 30/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - kl_loss: 33.4908 - loss: 13711.7793 - reconstruction_loss: 13666.1172 - total_loss: 13565.7344

# %%
x_decoded = vae.getPredictions(X_train_tensor)
predictedImage = x_decoded[0].reshape(150, 150, 3)

# %%
plt.imshow(predictedImage)

# %%
encoder.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[188], line 1
# ----> 1 encoder.predict()
#
# File A:\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:123, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#     121     # To get the full stack trace, call:
#     122     # `keras.config.disable_traceback_filtering()`
# --> 123     raise e.with_traceback(filtered_tb) from None
#     124 finally:
#     125     del filtered_tb
#
# File A:\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# TypeError: TensorFlowTrainer.predict() missing 1 required positional argument: 'x'

# %%
X_train_tensor.shape
# Out:
# TensorShape([3, 150, 150, 3])
